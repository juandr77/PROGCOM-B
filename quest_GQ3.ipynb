# %% [markdown]
# <a href="https://colab.research.google.com/github/juandr77/PROGCOM-B/blob/main/quest_GQ3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##¿que se puede hacer con este codigo?
#
#
#
# ```
# Ajustar los parámetros PID (Kp, Ki, Kd)
#
# Simular diferentes condiciones iniciales o perturbaciones
#
# Adaptarlo a un motor físico si usas Arduino y Python con pyserial
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np
K = 1.0
T = 0.5
dt = 0.01
time = np.arange(0, 5, dt)
Kp = 2.0
Ki = 1.0
Kd = 0.1
setpoint = 1.0
velocity = 0.0
error_sum = 0.0
last_error = 0.0
velocities = []
errors = []
for t in time:
    error = setpoint - velocity
    error_sum += error * dt
    d_error = (error - last_error) / dt
    u = Kp * error + Ki * error_sum + Kd * d_error
    velocity += dt * (-(1/T) * velocity + (K/T) * u)
    velocities.append(velocity)
    errors.append(error)
    last_error = error
plt.figure()
plt.plot(time, velocities, label="Velocidad del motor")
plt.plot(time, [setpoint]*len(time), 'r--', label="Setpoint")
plt.xlabel("Tiempo (s)")
plt.ylabel("Velocidad")
plt.legend()
plt.title("Control PID de velocidad del motor DC")
plt.grid(True)
plt.show()
