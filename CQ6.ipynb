# %% [markdown]
# <a href="https://colab.research.google.com/github/juandr77/PROGCOM-B/blob/main/CQ6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Captura de pantalla 2025-11-11 171136.png](data:image/png;base64,...)
